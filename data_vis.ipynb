# %%
import os
import pandas as pd

# %%
config = {"user_genre_dist_file":"./cornac/data_c/user_genre_dist.csv"}

actual_genre_dist = pd.read_csv(
            os.path.join(config["user_genre_dist_file"]),
            sep="\t",
        )
actual_genre_dist
# Out:
#       userID    Action  Thriller   Romance   Western  Children's   Mystery  \
# 0          0  0.029031  0.038749  0.054221  0.000000    0.128900  0.000000
# 1          1  0.157693  0.088141  0.061218  0.009615    0.000000  0.004808
# 2          2  0.147967  0.050813  0.017886  0.069106    0.013008  0.008130
# 3          3  0.376471  0.044118  0.011765  0.029412    0.014706  0.000000
# 4          4  0.071803  0.080713  0.072851  0.006289    0.012054  0.012054
# ...      ...       ...       ...       ...       ...         ...       ...
# 6035    6035  0.070938  0.086496  0.062260  0.009961    0.022997  0.014182
# 6036    6036  0.045794  0.169743  0.047321  0.010802    0.009774  0.025718
# 6037    6037  0.031249  0.000000  0.125001  0.000000    0.031249  0.000000
# 6038    6038  0.018855  0.053029  0.099998  0.006734    0.041582  0.069864
# 6039    6039  0.052331  0.062353  0.055394  0.006269    0.003783  0.016861
#
# ...

# %%
x = actual_genre_dist[actual_genre_dist["Documentary"]>0.00]
movies = pd.read_csv("./cornac/data_c/indexed_movies.csv")

movies = movies.drop(columns=movies.columns[0])

# %%
users = pd.read_csv("./cornac/data_c/u_id_mapping.csv", sep="\t")
users = users.drop(columns=users.columns[0])
gender_map = {"M": 0, "F": 1}
users["Gender"] = users["Gender"].map(gender_map)

# %%
rating_data_pd = pd.read_csv(
    "./cornac/data_c/indexed_interactions.csv",
    sep="\t",
    header=None,
    names=["userID", "itemID", "Rating", "Timestamp"],
)
# print(rating_data["itemID"].nunique())
# rating_data = rating_data.drop(columns=rating_data.columns[-1])
rating_data = rating_data_pd.to_numpy()
rating_data
# Out:
# array([[        0,         0,         5, 978300760],
#        [        0,         1,         3, 978302109],
#        [        0,         2,         3, 978301968],
#        ...,
#        [     6039,       365,         5, 956704746],
#        [     6039,       152,         4, 956715648],
#        [     6039,        26,         4, 956715569]])

# %%
m = pd.merge(rating_data_pd, movies, on="itemID", how="inner")
m
# Out:
#         userID  itemID  Rating  Timestamp  movieID  \
# 0            0       0       5  978300760     1193
# 1            0       1       3  978302109      661
# 2            0       2       3  978301968      914
# 3            0       3       4  978300275     3408
# 4            0       4       5  978824291     2355
# ...        ...     ...     ...        ...      ...
# 999606    6039     772       1  956716541     1091
# 999607    6039    1106       5  956704887     1094
# 999608    6039     365       5  956704746      562
# 999609    6039     152       4  956715648     1096
# 999610    6039      26       4  956715569     1097
#
#                                  genres
# 0                                 Drama
# 1          Animation|Children's|Musical
# 2                       Musical|Romance
# 3                                 Drama
# 4           Animation|Children's|Comedy
# ...                                 ...
# 999606                           Comedy
# ...

# %%
x = m[m["genres"].__contains__("Documentary")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/cornac/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 x = m[m["genres"].__contains__("Documentary")]
#
# ...

# %%
rating_data_pd = pd.read_csv(
    "./testing_set_seed123_ml100k.csv",
    sep=",",
    header=None,
    names=["userID", "iid", "Rating"],
)
rating_data_pd["label"]=1
# rating_data_pd
users = pd.read_csv("./cornac/data_c/ml-100k/u_id_mapping.csv", sep="\t")
users = users.drop(columns=users.columns[0])
gender_map = {"M": 0, "F": 1}
users["Gender"] = users["Gender"].map(gender_map)
users
# Out:
#      Gender  userID
# 0         0       0
# 1         1       1
# 2         0       2
# 3         0       3
# 4         0       4
# ..      ...     ...
# 938       1     938
# 939       0     939
# 940       1     940
# 941       1     941
# 942       0     942
#
# [943 rows x 2 columns]

# %%
new_df = pd.merge(rating_data_pd, users, on= "userID", how="inner")
new_df
# Out:
#        userID   iid  Rating  label  Gender
# 0         101   450       4      1       0
# 1         101   115       4      1       0
# 2         101   241       4      1       0
# 3         101   426       4      1       0
# 4         101   203       3      1       0
# ...       ...   ...     ...    ...     ...
# 20237     724  1015       4      1       0
# 20238     724   280       4      1       0
# 20239     724    98       3      1       0
# 20240     724   130       4      1       0
# 20241     724   175       4      1       0
#
# [20242 rows x 5 columns]

# %%
new_df.columns = ["uid","iid","rating","label", "u_gender"]
# Out:
#        userID   iid  Rating  label
# 0         101   450       4      1
# 1         101   115       4      1
# 2         101   241       4      1
# 3         101   426       4      1
# 4         101   203       3      1
# ...       ...   ...     ...    ...
# 20237     724  1015       4      1
# 20238     724   280       4      1
# 20239     724    98       3      1
# 20240     724   130       4      1
# 20241     724   175       4      1
#
# [20242 rows x 4 columns]

# %%
# new_df[new_df["Gender"]==1]
new_df.to_csv("m1100k.test.tsv")

# %%
rating_data_pd = pd.read_csv(
    "./testing_set_seed123_ml1m.csv",
    sep=",",
    header=None,
    names=["userID", "iid", "Rating"],
)
rating_data_pd["label"]=1
# rating_data_pd

users = pd.read_csv("./cornac/data_c/u_id_mapping.csv", sep="\t")
users = users.drop(columns=users.columns[0])
gender_map = {"M": 0, "F": 1}
users["Gender"] = users["Gender"].map(gender_map)

new_df = pd.merge(rating_data_pd, users, on= "userID", how="inner")
new_df
# Out:
#         userID   iid  Rating  label  Gender
# 0         6039   351       3      1       0
# 1         6039  2481       5      1       0
# 2         6039   159       4      1       0
# 3         6039   461       3      1       0
# 4         6039   288       4      1       0
# ...        ...   ...     ...    ...     ...
# 202331    2946   306       4      1       1
# 202332    2946   243       3      1       1
# 202333    2946   334       2      1       1
# 202334    2946   439       2      1       1
# 202335    2946  2234       3      1       1
#
# [202336 rows x 5 columns]

# %%
# new_df[new_df["Gender"]==1]
new_df.to_csv("ml1m.test.tsv")

# %%
rating_data_pd = pd.read_csv(
    "./training_set_seed123_ml1m.csv",
    sep=",",
    header=None,
    names=["userID", "iid", "Rating"],
)
rating_data_pd["label"]=1
# rating_data_pd

users = pd.read_csv("./cornac/data_c/u_id_mapping.csv", sep="\t")
users = users.drop(columns=users.columns[0])
gender_map = {"M": 0, "F": 1}
users["Gender"] = users["Gender"].map(gender_map)

new_df = pd.merge(rating_data_pd, users, on= "userID", how="inner")
new_df
# Out:
#         userID   iid  Rating  label  Gender
# 0         6039   669       4      1       0
# 1         6039   128       5      1       0
# 2         6039   323       4      1       0
# 3         6039    41       4      1       0
# 4         6039  1092       5      1       0
# ...        ...   ...     ...    ...     ...
# 694573    2946   527       4      1       1
# 694574    2946  1925       3      1       1
# 694575    2946  2135       4      1       1
# 694576    2946   475       5      1       1
# 694577    2946   502       4      1       1
#
# [694578 rows x 5 columns]

# %%
# new_df[new_df["Gender"]==1]
new_df.to_csv("ml1m.train.tsv")

# %%
rating_data_pd = pd.read_csv(
    "./val_set_seed123_ml1m.csv",
    sep=",",
    header=None,
    names=["userID", "iid", "Rating"],
)
rating_data_pd["label"]=1
# rating_data_pd

users = pd.read_csv("./cornac/data_c/u_id_mapping.csv", sep="\t")
users = users.drop(columns=users.columns[0])
gender_map = {"M": 0, "F": 1}
users["Gender"] = users["Gender"].map(gender_map)

new_df = pd.merge(rating_data_pd, users, on= "userID", how="inner")
new_df
# Out:
#         userID   iid  Rating  label  Gender
# 0         6039   364       4      1       0
# 1         6039   209       4      1       0
# 2         6039   617       5      1       0
# 3         6039   164       3      1       0
# 4         6039   693       5      1       0
# ...        ...   ...     ...    ...     ...
# 102692    2946   454       2      1       1
# 102693    2946   105       3      1       1
# 102694    2946   343       3      1       1
# 102695    2946  2099       4      1       1
# 102696    2946    89       3      1       1
#
# [102697 rows x 5 columns]

# %%
new_df.to_csv("ml1m.validation.tsv")

# %%
rating_data_pd = pd.read_csv(
    "./val_set_seed123_ml100k.csv",
    sep=",",
    header=None,
    names=["userID", "iid", "Rating"],
)
rating_data_pd["label"]=1
# rating_data_pd
users = pd.read_csv("./cornac/data_c/ml-100k/u_id_mapping.csv", sep="\t")
users = users.drop(columns=users.columns[0])
gender_map = {"M": 0, "F": 1}
users["Gender"] = users["Gender"].map(gender_map)
new_df = pd.merge(rating_data_pd, users, on= "userID", how="inner")
new_df
# Out:
#        userID  iid  Rating  label  Gender
# 0         101   25       3      1       0
# 1         101  310       3      1       0
# 2         101  161       4      1       0
# 3         101  710       5      1       0
# 4         101  365       2      1       0
# ...       ...  ...     ...    ...     ...
# 10366     678  575       3      1       0
# 10367     678  360       4      1       0
# 10368     724  875       4      1       0
# 10369     724  710       3      1       0
# 10370     724  645       4      1       0
#
# [10371 rows x 5 columns]

# %%
new_df.to_csv("ml100k.validation.tsv")

# %%
rating_data_pd = pd.read_csv(
    "./training_set_seed123_ml100k.csv",
    sep=",",
    header=None,
    names=["userID", "iid", "Rating"],
)
rating_data_pd["label"]=1
# rating_data_pd
users = pd.read_csv("./cornac/data_c/ml-100k/u_id_mapping.csv", sep="\t")
users = users.drop(columns=users.columns[0])
gender_map = {"M": 0, "F": 1}
users["Gender"] = users["Gender"].map(gender_map)
new_df = pd.merge(rating_data_pd, users, on= "userID", how="inner")
new_df
# Out:
#        userID  iid  Rating  label  Gender
# 0         101  177       4      1       0
# 1         101  289       4      1       0
# 2         101  153       4      1       0
# 3         101  361       4      1       0
# 4         101  321       4      1       0
# ...       ...  ...     ...    ...     ...
# 68669     724  421       1      1       0
# 68670     724  575       2      1       0
# 68671     724  964       1      1       0
# 68672     724  551       5      1       0
# 68673     724   51       4      1       0
#
# [68674 rows x 5 columns]

# %%
new_df.to_csv("ml100k.train.tsv")
